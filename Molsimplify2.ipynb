# %% [markdown]
# <a href="https://colab.research.google.com/github/inefable12/modelamientomolecular/blob/main/Molsimplify2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Requerimientos

# %%
# !pip install condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# !conda install conda-forge::molsimplify

# %% [markdown]
# # Ejemplos

# %%
# !molsimplify -h
# Out:
# TensorFlow connection successful.
# usage: molsimplify [-h] [-core CORE] [-oxstate OXSTATE] [-coord] [-geometry]
#                    [-geo] [-lig LIG] [-ligocc] [-spin SPIN]
#                    [-spinmultiplicity SPINMULTIPLICITY]
#                    [-multiplicity MULTIPLICITY] [-keepHs KEEPHS]
#                    [-skipANN SKIPANN] [-rundir]
#                    [-custom_data_dir CUSTOM_DATA_DIR] [-smicat]
#                    [-ligloc LIGLOC] [-ff FF] [-ffoption FFOPTION]
#                    [-ff_final_opt FF_FINAL_OPT]
#
# Welcome to molSimplify. Only basic usage is described here.
# For help on advanced modules, please refer to our documentation at molsimplify.mit.edu or provide additional commands to -h, as below:
# -h advanced: advanced structure generation help
# -h slabgen: slab builder help
# -h autocorr: automated correlation analysis help
# -h db: database search help
# -h inputgen: quantum chemistry code input file generation help
# ...

# %% [markdown]
# # Galio - Oh

# %%
# !molsimplify -lig "Ingresa tu SMILES" -ligocc 1 -smicat 5,10,16,31,39,52 -core iron -geometry oct -coord 6 -oxstate III -spin 5 -skipANN True

# %% [markdown]
# # Iron - Oh

# %%
# !molsimplify -lig "Ingresa tu SMILES" -ligocc 3 -smicat 12,14 -core iron -geometry oct -coord 6 -oxstate III -spin 6

# %% [markdown]
# # Cobalt - Td

# %%
# !molsimplify -lig "Ingresa tu SMILES" -ligocc 1 -smicat 26,28,39,41 -core cobalt -geometry td -coord 4 -oxstate II -spin 4
